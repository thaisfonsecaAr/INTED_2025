# %% [markdown]
# <a href="https://colab.research.google.com/github/thaisfonsecaAr/INTED_2025/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
idade = int(input('digite sua idade'))
if idade >= 16 :
  print('Você já pode votar.')
else:
  print('Você não pode votar')
# Out:
# digite sua idade 13
# Você não pode votar

# %%
#2
nota = int(input('digite sua nota'))
if nota >= 7:
 print ('aprovado')
else:
  print ('reprovado')
# Out:
# digite sua nota 3
# reprovado

# %%
#3
temperatura = int(input('digite a temperatura'))
if temperatura <15:
 print ('está fria')
elif 15<= temperatura <23:
  print ('está agradável')
elif 23<= temperatura <30:
 print ('está quente')
else:
  print('está muito quente')
# Out:
# digite a temperatura 18
# está agradável

# %%
#4
numero = int(input('digite o numero'))
if numero %2 == 0:
  print ('par')
else:
    print ('ímpar')
# Out:
# digite o numero 3
# ímpar

# %%
#7 – Você está desenvolvendo um calendário digital. Crie um programa que receba um ano e determine se ele é bissexto.
ano = int(input('digite o ano:'))
if ano % 4 ==0:
  print ('este ano é bissexto')
else:
  print ('este ano não é bissexto')
# Out:
# digite o ano: 2024
# este ano é bissexto

# %%
#8 – Um cinema utiliza preços diferentes para ingressos infantis e adultos. A partir da idade informada, exiba qual tipo de ingresso deve ser vendido.
idade = int(input('digite idade'))
if idade >=18:
  print ('ingresso adulto')
else:
    print ('ingresso infantil')
# Out:
# digite idade 3
# ingresso infantil
