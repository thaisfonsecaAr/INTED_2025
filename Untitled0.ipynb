# %% [markdown]
# <a href="https://colab.research.google.com/github/thaisfonsecaAr/INTED_2025/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=int(input('digite o número'))
if x %2 == 0:
 print('par')
else:
  print('ímpar')
# Out:
# digite o número 8
# par

# %%
nome=input('digite o nome')
if 'g' in nome:
  print('contêm g')
else:
  print('não contêm g')
# Out:
# digite o nome Thaís
# não contêm g

# %%
#1
num=int(input('digite um número'))
if num >10:
  print(num,'maior que 10!')
elif num <10:
  print(num,'é menor que 10!')
else:
  print(num,'é 10!!!')
# Out:
# digite um número2
# 2 é menor que 10!

# %%
#2
x=int(input('digite o número'))
if x %2 == 0:
 print('par')
else:
  print('ímpar')
# Out:
# digite o número 8732742684
# par

# %%
#3
nome=input('digite o nome')
if 'a' in nome:
  print('contêm a')
else:
  print('não contêm a')
# Out:
# digite o nome Lucas
# contêm a

# %%
#4
x=int(input('digite o número'))
if x %5 == 0:
 print('é divisível por 5')
else:
  print('não é divisível por 5')
# Out:
# digite o número 25
# é divisível por 5

# %%
#5
num=int(input('digite a temperatura'))
if num <=30:
  print(num,'está frio!')
else:
  print(num,'está calor!')
# Out:
# digite a temperatura 25
# 25 está frio!

# %%
#6
letra =input('digite S  ou N ')
if letra.lower() == 's':
  print('continuar')
elif letra.lower() == 'n':
  print('sair')
else:
  print('opção inválida')
# Out:
# digite S  ou N  d
# opção inválida

# %%
#7
num=int(input('digite um número'))
if num <0:
  print(num,'é negativo!')
elif num >0:
  print(num,'é positivo!')
else:
  print(num,'é zero!!!')
# Out:
# digite um número-2
# -2 é negativo!

# %%
#8
num
